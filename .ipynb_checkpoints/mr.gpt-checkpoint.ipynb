# %%
# D1 (add gemini api key before running)
# change the contains_icici_lombard_fuzzy() function and preprompt before running for other targets
# translated column will be added in last cell, dont run that directly now, run all cells sequentially
# !pip install google-genai pandas openpyxl deep-translator -q

import os
import json
import glob
import re
import time
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pandas as pd
from google import genai

# =========================
# 🔑 CONFIG
# =========================
# Ensure your API Key is handled securely in production environment
client = genai.Client(api_key="api_key")

BATCH_SIZE = 8

# =========================
# 🧠 UPDATED PREPROMPT (Aligned with Project Scope)
# =========================

PREPROMPT = """You are an expert insurance analyst extracting structured "Customer Truth" from unstructured data.

Your objective is to convert extremely low-signal comments into a HIGH-SIGNAL dataset using STRICT filtering.

-----------------------------------
### SIGNAL FILTER (STRICT)

A comment is VALID only if it contains:

1. Event → real-world incident  
   (e.g., accident, hospitalization, policy purchase)

2. Process → interaction with insurer  
   (e.g., claim filed, agent advice, service request)

3. Outcome → result of that interaction  
   (e.g., rejection, delay, approval, regret)

High Signal = Event + Process + Outcome
If ANY of the above is missing → EXCLUDE
ALL THREE must be present.
NO EXCEPTIONS.

-----------------------------------
### PRIMARY ENTITY RULE (HARD FILTER)

Target insurer: ICICI Lombard

INCLUDE ONLY IF:
- The Event, Process, AND Outcome are ALL about ICICI Lombard

EXCLUDE if:
- ICICI Lombard is mentioned but NOT central to the experience
- The actual complaint is about another insurer
- It is a comparison, suggestion, or list mention

Test:
If ICICI Lombard is removed and meaning remains → EXCLUDE

-----------------------------------
### NOISE FILTERS (STRICT REJECTION)

Immediately EXCLUDE if comment falls into ANY category:

1. Market Comparison  
   (comparison between insurers without lived experience)

2. Duplicate / Near Duplicate  
   (same complaint phrased similarly)

3. Generic Commentary  
   (e.g., "fraud company", "worst insurer")

4. Generic Opinion  
   (broad statements without specific experience)

5. Missing full signal chain (Event + Process + Outcome)

-----------------------------------
### EXPERIENCE VALIDATION

INCLUDE ONLY IF:
- First-hand experience (NOT hearsay)
- Contains a clear interaction journey
- Contains a clear outcome tied to ICICI Lombard

If ambiguous → EXCLUDE

-----------------------------------
### TAXONOMY RULES (EXACT MATCH ONLY)

Stage:
- Pre-Sale Misrepresentation
- Onboarding & Policy Understanding
- Servicing & Policy Admin
- Early Regret / Exit Intent
- Claims Experience

Root Cause:
- Sales Pressure or Coercion
- Misrepresentation / Incomplete Explanation
- Product Design or Complexity
- Process / Documentation Friction
- Communication / Language Barrier

Channel:
- Bank / Bancassurance
- Agent / Advisor
- Branch / Customer Service
- Digital / App / Website
- Claims / TPA
- Unknown

Emotion:
- Anger
- Betrayal
- Confusion
- Resignation

Severity:
- High, Medium, Low

Actionability Score (1-5):
- 5 = immediate process fix possible
- 1 = vague complaint

Fixability Score (1-5):
- 5 = easy to fix (e.g., website bug)
- 1 = structural/legal issue.

Evidence Strength:
- High: Mentions specific dates, branch names, policy numbers, or staff names.
- Medium: Clear incident but lacks specific identifiers.
- Low: Valid complaint but vague on details.
   
-----------------------------------
### STRICT CLASSIFICATION RULES

- Do NOT infer missing steps
- Do NOT assume outcome
- Do NOT hallucinate process
- If chain is incomplete → EXCLUDE
- If multiple interpretations exist → EXCLUDE

-----------------------------------
### OUTPUT RULES

- Default bias = EXCLUDE
- Only include HIGH-CONFIDENCE cases
- Be conservative, not generous
- Maximize precision over recall

-----------------------------------
### OUTPUT SCHEMA (STRICT JSON)

Return array:

{
    "include": true/false,
    "product_hint": "life/health/savings/unknown",
    "stage": "...",
    "primary_breakdown": "...",
    "root_cause": "...",
    "channel": "...",
    "emotion": "...",
    "severity": "...",
    "summary": "must explicitly contain event + process + outcome",
    "actionability_score_5": 1-5,
    "fixability_score_5": 1-5,
    "geo_hint": "City+State+Country if mentioned/implied, else 'unknown'",
    "evidence_strength": "High/Medium/Low"
}

-----------------------------------
COMMENTS:
"""

# =========================
# 📂 LOAD DATA
# =========================
def load_all_yt_data(directory):
    all_data = []
    json_paths = glob.glob(os.path.join(directory, "**/*.info.json"), recursive=True)

    for j_path in json_paths:
        try:
            with open(j_path, 'r', encoding='utf-8') as f:
                meta = json.load(f)
            all_data.append({
                'title': meta.get('title'),
                'video_id': meta.get('id'),
                'comments': meta.get('comments', [])
            })
        except Exception as e:
            print(f"Error loading {j_path}: {e}")
    return all_data

# =========================
# 🔍 FILTER + DEDUP
# =========================
def is_fuzzy_match(word, target, threshold=0.8):
    return SequenceMatcher(None, word.lower(), target.lower()).ratio() >= threshold

def contains_icici_lombard_fuzzy(text):
    text_lower = text.lower()
    words = text_lower.split()

    # ✅ Include if Lombard present
    return any(
        is_fuzzy_match(w, "lombard")
        for w in words
    )


def normalize_text(text):
    text = text.lower()
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

# =========================
# 🕒 TIME + LINK
# =========================
def convert_timestamp_ist(ts):
    if ts:
        return (datetime.utcfromtimestamp(ts) + timedelta(hours=5, minutes=30)).strftime("%Y-%m-%d %H:%M:%S")
    return None

def generate_comment_link(video_id, comment_id):
    if video_id and comment_id:
        return f"https://www.youtube.com/watch?v={video_id}&lc={comment_id}"
    return None

# =========================
# 🤖 BATCH GEMINI CALL
# =========================
def process_batch(comments, retries=3):
    for attempt in range(retries):
        try:
            joined = "\n\n---\n\n".join(comments)
            response = client.models.generate_content(
                model="gemini-2.5-flash-lite", # Using latest stable lite model
                contents=PREPROMPT + joined,
                config={
                    "temperature": 0.1, # Lower temperature for classification accuracy 
                    "response_mime_type": "application/json"
                }
            )
            return json.loads(response.text.strip())
        except Exception as e:
            print(f"Gemini Error (Attempt {attempt+1}): {e}")
            time.sleep(10)
    return None

# =========================
# 🚀 MAIN PIPELINE
# =========================
base_dir = "ICICI_Lombard_Today"
raw_dataset = load_all_yt_data(base_dir)

# 1. Filter: Enforcing length and brand mention 
filtered_comments = [
    (video, comment) 
    for video in raw_dataset 
    for comment in video['comments']
    if (len(comment.get('text', '')) > 200 and contains_icici_lombard_fuzzy(comment.get('text', '')))
]

# 2. Dedup: High quality bar requirement 
deduped_comments = []
seen_norms = []
for video, comment in filtered_comments:
    norm = normalize_text(comment.get('text', ''))
    if not any(SequenceMatcher(None, norm, existing).ratio() > 0.85 for existing in seen_norms):
        seen_norms.append(norm)
        deduped_comments.append((video, comment))

print(f"Starting analysis on {len(deduped_comments)} unique comments...")

# 3. Batch processing
final_dataset = []
for i in range(0, len(deduped_comments), BATCH_SIZE):
    batch = deduped_comments[i:i+BATCH_SIZE]
    texts = [c[1].get('text', '') for c in batch]
    results = process_batch(texts)

    if not results or len(results) != len(batch):
        continue

    for (video, comment), result in zip(batch, results):
        if result.get("include"):
            final_dataset.append({
                "source": "YouTube",
                "link": generate_comment_link(video.get("video_id"), comment.get("id")),
                "date_time": convert_timestamp_ist(comment.get("timestamp")),
                "original_text": comment.get('text', ''),
                "length": len(comment.get('text', '')),
                "geo_hint": result.get("geo_hint"),
                "engagement_signal": comment.get("like_count", 0),
                "product_hint": result.get("product_hint"),
                "stage": result.get("stage"),
                "primary_breakdown_point": result.get("primary_breakdown"), # Critical Scope Field 
                "channel": result.get("channel"),
                "root_cause": result.get("root_cause"),
                "emotion": result.get("emotion"),
                "emotion_severity": result.get("severity"),
                "summary_insight": result.get("summary"),
                "actionability_score_5": result.get("actionability_score_5"),
                "fixability_score_5": result.get("fixability_score_5"),
                "evidence_strength": result.get("evidence_strength")
            })
    
    print(f"Processed batch {i//BATCH_SIZE + 1}. Current Total: {len(final_dataset)}")
    time.sleep(2) # Rate limit management

# =========================
# 📤 SAVE (D1 Deliverable) [cite: 32]
# =========================
df = pd.DataFrame(final_dataset)
df.to_csv("structured_customer_truth.csv", index=False)
print(f"\n✅ Pipeline Complete. Saved {len(df)} high-quality entries.")
# Out:
# Starting analysis on 249 unique comments...
# Processed batch 1. Current Total: 5
# Processed batch 2. Current Total: 8
# Processed batch 3. Current Total: 10
# Processed batch 4. Current Total: 14
# Processed batch 5. Current Total: 19
# Processed batch 6. Current Total: 23
# Processed batch 8. Current Total: 26
# Processed batch 9. Current Total: 29
# Processed batch 11. Current Total: 32
# Processed batch 12. Current Total: 35
# Processed batch 13. Current Total: 37
# Processed batch 14. Current Total: 43
# Processed batch 15. Current Total: 47
# Processed batch 16. Current Total: 50
# Processed batch 17. Current Total: 57
# Processed batch 18. Current Total: 57
# Processed batch 19. Current Total: 61
# Processed batch 21. Current Total: 64
# Processed batch 22. Current Total: 70
# Processed batch 23. Current Total: 75
# Processed batch 24. Current Total: 82
# Processed batch 25. Current Total: 86
# Processed batch 26. Current Total: 92
# Processed batch 27. Current Total: 98
# ...

# %%
# D2 (add your gemini api key before running)
# change preprompt before running for other targets
# D2_Insight_Summary.md is final D2

import pandas as pd
import json
from google import genai

# =========================
# 🔑 CONFIG
# =========================
client = genai.Client(api_key="api_key")
INPUT_FILE = "structured_customer_truth.csv"

def generate_analytical_deliverables():
    # 1. Load the D1 Dataset
    try:
        df = pd.read_csv(INPUT_FILE)
    except FileNotFoundError:
        print(f"Error: {INPUT_FILE} not found. Please run the D1 pipeline first.")
        return

    if df.empty:
        print("No data found in the CSV to analyze.")
        return

    print(f"📊 Analyzing {len(df)} records for D2...")

    # 2. Prepare Data for Synthesis
    # We aggregate the key fields so Gemini has context without hitting token limits
    context_data = df[['stage', 'root_cause', 'summary_insight', 'channel']].to_string()

    # =========================
    # 🧠 D2: INSIGHT SUMMARY PROMPT
    # =========================
    d2_prompt = f"""
    You are a Senior Strategic Analyst. Based on the following customer complaint data for ICICI Lombard, 
    generate a 'D2 - Insight Summary' report.
    
    DATA:
    {context_data}
    
    REPORT REQUIREMENTS:
    - RECURRING THEMES: What are the primary friction points appearing in the data?
    - SURPRISE PATTERNS: Are there any anomalies or unexpected correlations between channels and emotions?
    - STRONG SIGNALS: Identify specific, high-severity issues that require immediate attention.
    - dont make the report longer than it needs to be
    - the report will be read by the ceo, so keep language formal and non-exaggerated
    - dont mention specific cases
    - dont mention date at top of report
    - ACTIONABLE INSIGHTS: Provide 1–5 high-impact, non-obvious actions that directly address the strongest signals. 
      Each action must:
      - be specific and implementable (not generic advice)
      - tie clearly to a root cause identified above
      - reflect systemic or structural fixes (not frontline-level suggestions)
    """

    print("Generating D2: Insight Summary...")
    d2_response = client.models.generate_content(
        model="gemini-2.5-flash-lite",
        contents=d2_prompt
    )

    with open("D2_Insight_Summary.md", "w") as f:
        f.write("# D2 Deliverable: Insight Summary\n\n")
        f.write(d2_response.text)

    print("\n✅ Deliverables Complete:")
    print("- D2 saved to 'D2_Insight_Summary.md'")

if __name__ == "__main__":
    generate_analytical_deliverables()
# Out:
# 📊 Analyzing 110 records for D2...
# Generating D2: Insight Summary...
#
# ✅ Deliverables Complete:
# - D2 saved to 'D2_Insight_Summary.md'

# %%
# D3 final (add your gemini api key before running)
# preprompt can remain same, but double check
# D3_Full_Taxonomy_Audit.md is final D3

import pandas as pd
import time
from google import genai

# =========================
# 🔑 CONFIG
# =========================
client = genai.Client(api_key="api_key") # Replace with your key
INPUT_FILE = "structured_customer_truth.csv"
OUTPUT_EXCEL = "structured_customer_truth_rowsnumbered.xlsx"
BATCH_SIZE = 5 
MAX_RETRIES = 5 

def generate_numbered_deliverables():
    try:
        df = pd.read_csv(INPUT_FILE)
    except FileNotFoundError:
        print(f"Error: {INPUT_FILE} not found.")
        return

    if 'audit_id' not in df.columns:
        df.insert(0, 'audit_id', range(len(df)))

    df.to_excel(OUTPUT_EXCEL, index=False)
    print(f"✅ Excel file created: {OUTPUT_EXCEL}")

    total_rows = len(df)
    full_d3_report = []

    print(f"🚀 Starting Audit on {total_rows} rows...")

    for start_idx in range(0, total_rows, BATCH_SIZE):
        end_idx = min(start_idx + BATCH_SIZE, total_rows)
        batch_df = df.iloc[start_idx:end_idx]
        
        formatted_rows = []
        for _, row in batch_df.iterrows():
            # UPDATED: Included Channel, Emotion, and Severity in the data context
            entry = (
                f"[AUDIT_ID: {row['audit_id']}]\n"
                f"Stage: {row['stage']}\n"
                f"Root Cause: {row['root_cause']}\n"
                f"Channel: {row.get('channel', 'N/A')}\n"
                f"Emotion: {row.get('emotion', 'N/A')}\n"
                f"Severity: {row.get('emotion_severity', 'N/A')}\n"
                f"Summary: {row['summary_insight']}\n"
                f"-----------------------"
            )
            formatted_rows.append(entry)
        
        context_data = "\n".join(formatted_rows)

        # UPDATED: Prompt now includes the full taxonomy for the Auditor to reference
        d3_batch_prompt = f"""
        You are a Data Auditor. Review these {len(batch_df)} rows for taxonomy alignment.
        
        REFERENCE TAXONOMY:
        - Stage: Pre-Sale Misrepresentation, Onboarding & Policy Understanding, Servicing & Policy Admin, Early Regret / Exit Intent, Claims Experience
        - Root Cause: Sales Pressure or Coercion, Misrepresentation / Incomplete Explanation, Product Design or Complexity, Process / Documentation Friction, Communication / Language Barrier
        - Channel: Bank / Bancassurance, Agent / Advisor, Branch / Customer Service, Digital / App / Website, Claims / TPA, Unknown
        - Emotion: Anger, Betrayal, Confusion, Resignation
        - Severity: High, Medium, Low

        STRICT FORMATTING RULES:
        1. You MUST use the EXACT template below for EVERY [AUDIT_ID].
        2. Every ID must have its own block.
        3. For every field, determine if the value is "Accurate" or "Forced Fit - [Reason]".

        REQUIRED TEMPLATE PER ID:
        [AUDIT_ID: X]
        Stage: [Accurate / Forced Fit - Reason]
        Root Cause: [Accurate / Forced Fit - Reason]
        Channel: [Accurate / Forced Fit - Reason]
        Emotion: [Accurate / Forced Fit - Reason]
        Severity: [Accurate / Forced Fit - Reason]

        DATA:
        {context_data}
        """

        # =========================
        # 🔄 RETRY LOGIC BLOCK
        # =========================
        success = False
        for attempt in range(MAX_RETRIES):
            try:
                print(f"Auditing AUDIT_IDs {start_idx} to {end_idx-1} (Attempt {attempt+1})...")
                response = client.models.generate_content(
                    model="gemini-2.5-flash-lite",
                    config={"temperature": 0.1},
                    contents=d3_batch_prompt
                )
                audit_text = response.text.strip()
                full_d3_report.append(audit_text)
                success = True
                break 
            except Exception as e:
                wait_time = (attempt + 1) * 10
                print(f"⚠️ Error at ID {start_idx}: {e}. Retrying in {wait_time}s...")
                time.sleep(wait_time)

        if not success:
            error_msg = f"[AUDIT_ID: {start_idx}-{end_idx-1}]\nAlignment: ERROR - Model unavailable after {MAX_RETRIES} attempts."
            full_d3_report.append(error_msg)

        time.sleep(1)

    with open("D3_Full_Taxonomy_Audit.md", "w", encoding="utf-8") as f:
        f.write("# D3 Deliverable: Full Taxonomy Audit\n")
        f.write(f"Synchronized with: {OUTPUT_EXCEL}\n\n")
        f.write("\n\n---\n\n".join(full_d3_report))

    print(f"\n✨ Done! Full dimension audit complete.")

if __name__ == "__main__":
    generate_numbered_deliverables()
# Out:
# ✅ Excel file created: structured_customer_truth_rowsnumbered.xlsx
# 🚀 Starting Audit on 110 rows...
# Auditing AUDIT_IDs 0 to 4 (Attempt 1)...
# Auditing AUDIT_IDs 5 to 9 (Attempt 1)...
# Auditing AUDIT_IDs 10 to 14 (Attempt 1)...
# Auditing AUDIT_IDs 15 to 19 (Attempt 1)...
# Auditing AUDIT_IDs 20 to 24 (Attempt 1)...
# Auditing AUDIT_IDs 25 to 29 (Attempt 1)...
# Auditing AUDIT_IDs 30 to 34 (Attempt 1)...
# Auditing AUDIT_IDs 35 to 39 (Attempt 1)...
# Auditing AUDIT_IDs 40 to 44 (Attempt 1)...
# Auditing AUDIT_IDs 45 to 49 (Attempt 1)...
# Auditing AUDIT_IDs 50 to 54 (Attempt 1)...
# Auditing AUDIT_IDs 55 to 59 (Attempt 1)...
# Auditing AUDIT_IDs 60 to 64 (Attempt 1)...
# Auditing AUDIT_IDs 65 to 69 (Attempt 1)...
# Auditing AUDIT_IDs 70 to 74 (Attempt 1)...
# Auditing AUDIT_IDs 75 to 79 (Attempt 1)...
# Auditing AUDIT_IDs 80 to 84 (Attempt 1)...
# Auditing AUDIT_IDs 85 to 89 (Attempt 1)...
# ...

# %%
# add translation column translate
# structured_customer_truth_translated.xlsx is the final D1

import pandas as pd
import time
from deep_translator import GoogleTranslator

# =========================
# 🔑 CONFIG
# =========================
# Input from the previously numbered file
INPUT_EXCEL = "structured_customer_truth_rowsnumbered.xlsx"
OUTPUT_EXCEL = "structured_customer_truth_translated.xlsx"

def translate_dataset():
    # 1. Load the numbered file
    try:
        df = pd.read_excel(INPUT_EXCEL)
        print(f"📖 Loaded {len(df)} rows from {INPUT_EXCEL}")
    except FileNotFoundError:
        print(f"Error: {INPUT_EXCEL} not found. Please run the numbering script first.")
        return

    # 2. Initialize Translator
    # 'auto' will detect Hindi, Rajasthani, or English automatically
    translator = GoogleTranslator(source='auto', target='en')

    print("🌐 Starting Translation (this may take a minute)...")

    # 3. Translation Logic
    def safe_translate(text):
        if pd.isna(text) or str(text).strip() == "":
            return ""
        try:
            # We add a tiny sleep to avoid rate limiting
            time.sleep(0.2) 
            return translator.translate(text)
        except Exception as e:
            print(f"⚠️ Translation error: {e}")
            return text # Fallback to original if it fails

    # Apply translation to the 'original_text' column
    df['translated_text'] = df['original_text'].apply(safe_translate)

    # 4. Save the Final Result
    # Reordering columns so 'translated_text' is near 'original_text' for easier review
    cols = list(df.columns)
    if 'original_text' in cols:
        idx = cols.index('original_text') + 1
        cols.insert(idx, cols.pop(cols.index('translated_text')))
        df = df[cols]

    df.to_excel(OUTPUT_EXCEL, index=False)
    print(f"✅ Success! Translated file saved as: {OUTPUT_EXCEL}")

if __name__ == "__main__":
    # Ensure you have deep-translator installed: pip install deep-translator
    translate_dataset()
# Out:
# 📖 Loaded 110 rows from structured_customer_truth_rowsnumbered.xlsx
# 🌐 Starting Translation (this may take a minute)...
# ✅ Success! Translated file saved as: structured_customer_truth_translated.xlsx
